# %% [markdown]
# <a href="https://colab.research.google.com/github/haviet12/Artificial_Inteligent/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import load_model
model_100=load_model('/content/drive/MyDrive/MyPicture/model.h5')

# %%
from keras.utils import load_img, img_to_array
import matplotlib.pyplot as plt

img= load_img('/content/drive/MyDrive/Ảnh/mpic.jpg')
plt.imshow(img)
plt.show()

# %%
img =load_img('/content/drive/MyDrive/Ảnh/mpic.jpg', target_size=(32,32))
plt.imshow(img)

# %%
img = img_to_array(img)
img= img.reshape(1, 32*32*3)
img = img.astype('float32')/255.0
import numpy as np
np.argmax(model_100.predict(img), axis=-1)
# Out:
# 1/1 [==============================] - 0s 263ms/step
# array([43])

# %%
from matplotlib.image import imread
folder ='/content/drive/MyDrive/PICTURE/Mpic/'
for i in range(8):
  plt.subplot(2,4,i+1)
  filename = folder +'Ha'+ str(i+1)+'.jpg'
  img  = imread(filename)
  plt.imshow(img)
plt.show()
